# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
df = sns.load_dataset("tips")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
df.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
df.describe().T
# Out:
#             count       mean       std   min      25%     50%      75%    max
# total_bill  244.0  19.785943  8.902412  3.07  13.3475  17.795  24.1275  50.81
# tip         244.0   2.998279  1.383638  1.00   2.0000   2.900   3.5625  10.00
# size        244.0   2.569672  0.951100  1.00   2.0000   2.000   3.0000   6.00

# %%
df.describe(include='all').T
# Out:
#             count unique     top freq       mean       std   min      25%  \
# total_bill  244.0    NaN     NaN  NaN  19.785943  8.902412  3.07  13.3475
# tip         244.0    NaN     NaN  NaN   2.998279  1.383638   1.0      2.0
# sex           244      2    Male  157        NaN       NaN   NaN      NaN
# smoker        244      2      No  151        NaN       NaN   NaN      NaN
# day           244      4     Sat   87        NaN       NaN   NaN      NaN
# time          244      2  Dinner  176        NaN       NaN   NaN      NaN
# size        244.0    NaN     NaN  NaN   2.569672    0.9511   1.0      2.0
#
#                50%      75%    max
# total_bill  17.795  24.1275  50.81
# tip            2.9   3.5625   10.0
# sex            NaN      NaN    NaN
# smoker         NaN      NaN    NaN
# day            NaN      NaN    NaN
# time           NaN      NaN    NaN
# size           2.0      3.0    6.0

# %%
# Finfding missing value
df.isna().sum()
# df.null().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
df[df.duplicated()]
# Out:
#      total_bill  tip     sex smoker   day   time  size
# 202        13.0  2.0  Female    Yes  Thur  Lunch     2

# %%
df.duplicated().value_counts()
# Out:
# False    243
# True       1
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (244, 7)

# %%
df[df.duplicated()].count()
# Out:
# total_bill    1
# tip           1
# sex           1
# smoker        1
# day           1
# time          1
# size          1
# dtype: int64

# %%
# Missing values handling

# %%
# no missing values here so remove duplicates
df =df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# Analysis

# %%
# Finding unique values in each column
for col in df.columns:
    print(col)
    print(df[col].unique())
# Out:
# total_bill
# [16.99 10.34 21.01 23.68 24.59 25.29  8.77 26.88 15.04 14.78 10.27 35.26
#  15.42 18.43 14.83 21.58 10.33 16.29 16.97 20.65 17.92 20.29 15.77 39.42
#  19.82 17.81 13.37 12.69 21.7  19.65  9.55 18.35 15.06 20.69 17.78 24.06
#  16.31 16.93 18.69 31.27 16.04 17.46 13.94  9.68 30.4  18.29 22.23 32.4
#  28.55 18.04 12.54 10.29 34.81  9.94 25.56 19.49 38.01 26.41 11.24 48.27
#  13.81 11.02 17.59 20.08 16.45  3.07 20.23 15.01 12.02 17.07 26.86 25.28
#  14.73 10.51 27.2  22.76 17.29 19.44 16.66 10.07 32.68 15.98 34.83 13.03
#  18.28 24.71 21.16 28.97 22.49  5.75 16.32 22.75 40.17 27.28 12.03 12.46
#  11.35 15.38 44.3  22.42 20.92 15.36 20.49 25.21 18.24 14.31 14.    7.25
#  38.07 23.95 25.71 17.31 29.93 10.65 12.43 24.08 11.69 13.42 14.26 15.95
#  12.48 29.8   8.52 14.52 11.38 22.82 19.08 20.27 11.17 12.26 18.26  8.51
#  14.15 16.   13.16 17.47 34.3  41.19 27.05 16.43  8.35 18.64 11.87  9.78
#   7.51 14.07 13.13 17.26 24.55 19.77 29.85 48.17 25.   13.39 16.49 21.5
# ...

# %%
df.day.unique()
# unique values of institutes
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
for col in df.columns:
    print(f'{col}:{df[col].nunique()}')
# Out:
# total_bill:229
# tip:123
# sex:2
# smoker:2
# day:4
# time:2
# size:6

# %%
df[['day','time']]
# Out:
#       day    time
# 0     Sun  Dinner
# 1     Sun  Dinner
# 2     Sun  Dinner
# 3     Sun  Dinner
# 4     Sun  Dinner
# ..    ...     ...
# 239   Sat  Dinner
# 240   Sat  Dinner
# 241   Sat  Dinner
# 242   Sat  Dinner
# 243  Thur  Dinner
#
# [243 rows x 2 columns]

# %%
df.loc[17] #gives whole row
# Out:
# total_bill     16.29
# tip             3.71
# sex             Male
# smoker            No
# day              Sun
# time          Dinner
# size               3
# Name: 17, dtype: object

# %%
# Change the value
import pandas as pd
print('before',df['day'][17])
df['day'] = df['day'].astype(object)  # Convert to object type to prevent categorical error
df['day'][17] = 'Mon'
print('after',df['day'][1])
df.loc[1] #gives whole row

# changing back to original
df['day'][17] = 'Sun'
df.loc[17] #gives whole row
# Out:
# before Sun
# after Sun
# C:\Users\User\AppData\Local\Temp\ipykernel_11628\492987093.py:5: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['day'][17] = 'Mon'
# ...

# %%
df[df['day']=='Sun']
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 0         16.99  1.01  Female     No  Sun  Dinner     2
# 1         10.34  1.66    Male     No  Sun  Dinner     3
# 2         21.01  3.50    Male     No  Sun  Dinner     3
# 3         23.68  3.31    Male     No  Sun  Dinner     2
# 4         24.59  3.61  Female     No  Sun  Dinner     4
# ..          ...   ...     ...    ...  ...     ...   ...
# 186       20.90  3.50  Female    Yes  Sun  Dinner     3
# 187       30.46  2.00    Male    Yes  Sun  Dinner     5
# 188       18.15  3.50  Female    Yes  Sun  Dinner     3
# 189       23.10  4.00    Male    Yes  Sun  Dinner     3
# 190       15.69  1.50    Male    Yes  Sun  Dinner     2
#
# [76 rows x 7 columns]

# %%
df[df['day']=='Sun'].count()
# Out:
# total_bill    76
# tip           76
# sex           76
# smoker        76
# day           76
# time          76
# size          76
# dtype: int64

# %%
df.query('day == "Sun"')
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 0         16.99  1.01  Female     No  Sun  Dinner     2
# 1         10.34  1.66    Male     No  Sun  Dinner     3
# 2         21.01  3.50    Male     No  Sun  Dinner     3
# 3         23.68  3.31    Male     No  Sun  Dinner     2
# 4         24.59  3.61  Female     No  Sun  Dinner     4
# ..          ...   ...     ...    ...  ...     ...   ...
# 186       20.90  3.50  Female    Yes  Sun  Dinner     3
# 187       30.46  2.00    Male    Yes  Sun  Dinner     5
# 188       18.15  3.50  Female    Yes  Sun  Dinner     3
# 189       23.10  4.00    Male    Yes  Sun  Dinner     3
# 190       15.69  1.50    Male    Yes  Sun  Dinner     2
#
# [76 rows x 7 columns]

# %%
df.query('tip <1.1')
# colum with tip<1.1
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 0         16.99  1.01  Female     No  Sun  Dinner     2
# 67         3.07  1.00  Female    Yes  Sat  Dinner     1
# 92         5.75  1.00  Female    Yes  Fri  Dinner     2
# 111        7.25  1.00  Female     No  Sat  Dinner     1
# 236       12.60  1.00    Male    Yes  Sat  Dinner     2

# %%
df['day'][df['tip'] < 1.1]
# colum with tip<1.1
# Out:
# 0      Sun
# 67     Sat
# 92     Fri
# 111    Sat
# 236    Sat
# Name: day, dtype: object

# %%
df[['day','sex']][df['tip'] < 1.1]
# Gender who gives tips <1.1 w.r.t weekdays
# Out:
#      day     sex
# 0    Sun  Female
# 67   Sat  Female
# 92   Fri  Female
# 111  Sat  Female
# 236  Sat    Male

# %%
# how many smokers
df[df['smoker'] == 'Yes'].count()
# Out:
# total_bill    92
# tip           92
# sex           92
# smoker        92
# day           92
# time          92
# size          92
# dtype: int64

# %%
df.loc[50:60, 'total_bill':'smoker']
# access 50 to 60 rows with colums starting from total_bill to smoker
# Out:
#     total_bill   tip     sex smoker
# 50       12.54  2.50    Male     No
# 51       10.29  2.60  Female     No
# 52       34.81  5.20  Female     No
# 53        9.94  1.56    Male     No
# 54       25.56  4.34    Male     No
# 55       19.49  3.51    Male     No
# 56       38.01  3.00    Male    Yes
# 57       26.41  1.50  Female     No
# 58       11.24  1.76    Male    Yes
# 59       48.27  6.73    Male     No
# 60       20.29  3.21    Male    Yes

# %%
df.iloc[50:60, 0:2]
# access first 2 colums with rows from 50 to 60
# Out:
#     total_bill   tip
# 50       12.54  2.50
# 51       10.29  2.60
# 52       34.81  5.20
# 53        9.94  1.56
# 54       25.56  4.34
# 55       19.49  3.51
# 56       38.01  3.00
# 57       26.41  1.50
# 58       11.24  1.76
# 59       48.27  6.73

# %%
df.iloc[50:60, 0:5].drop('day', axis = 1).head(3)
# remove day column
# Out:
#     total_bill  tip     sex smoker
# 50       12.54  2.5    Male     No
# 51       10.29  2.6  Female     No
# 52       34.81  5.2  Female     No

# %%
df.iloc[50:60, 0:5].drop(['day','sex'], axis = 1)
# remove 2 column - day and sex
# Out:
#     total_bill   tip smoker
# 50       12.54  2.50     No
# 51       10.29  2.60     No
# 52       34.81  5.20     No
# 53        9.94  1.56     No
# 54       25.56  4.34     No
# 55       19.49  3.51     No
# 56       38.01  3.00    Yes
# 57       26.41  1.50     No
# 58       11.24  1.76    Yes
# 59       48.27  6.73     No

# %%
df.sort_values(by='tip', ascending = False).head()
# Out:
#      total_bill    tip   sex smoker   day    time  size
# 170       50.81  10.00  Male    Yes   Sat  Dinner     3
# 212       48.33   9.00  Male     No   Sat  Dinner     4
# 23        39.42   7.58  Male     No   Sat  Dinner     4
# 59        48.27   6.73  Male     No   Sat  Dinner     4
# 141       34.30   6.70  Male     No  Thur   Lunch     6

# %%
df.sort_values(by='tip', ascending = False).head(1)
# Out:
#      total_bill   tip   sex smoker  day    time  size
# 170       50.81  10.0  Male    Yes  Sat  Dinner     3

# %%
df.sort_values(by='tip', ascending = False).drop(['smoker'], axis=1).head(1)
# Out:
#      total_bill   tip   sex  day    time  size
# 170       50.81  10.0  Male  Sat  Dinner     3

# %%
df.groupby('sex')['smoker'].count()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11628\1074055276.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('sex')['smoker'].count()
# sex
# Male      157
# Female     86
# Name: smoker, dtype: int64

# %%
df.groupby('smoker')['tip'].mean()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11628\2966249494.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('smoker')['tip'].mean()
# smoker
# Yes    3.019674
# No     2.991854
# Name: tip, dtype: float64

# %%
df.groupby(['sex','smoker'])['tip'].mean()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11628\1239790927.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(['sex','smoker'])['tip'].mean()
# sex     smoker
# Male    Yes       3.051167
#         No        3.113402
# Female  Yes       2.960625
#         No        2.773519
# Name: tip, dtype: float64
